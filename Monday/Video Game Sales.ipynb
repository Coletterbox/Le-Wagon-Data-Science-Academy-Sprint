# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('vgsales.csv')

# %%
df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
df.tail(10)
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %%
df.Name # accessing by column name - bracket notation also works
# Out:
# 0                                              Wii Sports
# 1                                       Super Mario Bros.
# 2                                          Mario Kart Wii
# 3                                       Wii Sports Resort
# 4                                Pokemon Red/Pokemon Blue
#                                ...
# 16593                  Woody Woodpecker in Crazy Castle 5
# 16594                       Men in Black II: Alien Escape
# 16595    SCORE International Baja 1000: The Official Game
# 16596                                          Know How 2
# 16597                                    Spirits & Spells
# Name: Name, Length: 16598, dtype: object

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.iloc[2:5]
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.iloc[2,1]
# Out:
# 'Mario Kart Wii'

# %%
sns.countplot(data=df.head(10), x='Name')

# %%
#sns.countplot(data=df, x='Name', y='EU_sales')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-004ebf7108f3> in <module>
# ----> 1 sns.countplot(data=df, x='Name', y='EU_sales')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3581         y = x
#    3582     elif x is not None and y is not None:
# -> 3583         raise ValueError("Cannot pass values for both `x` and `y`")
#    3584
#    3585     plotter = _CountPlotter(
#
# ValueError: Cannot pass values for both `x` and `y`

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
# df.sort_values(by="Global_Sales", ascending=False)

# %%
df['Publisher']
# Out:
# 0          Nintendo
# 1          Nintendo
# 2          Nintendo
# 3          Nintendo
# 4          Nintendo
#             ...
# 16593         Kemco
# 16594    Infogrames
# 16595    Activision
# 16596      7G//AMES
# 16597       Wanadoo
# Name: Publisher, Length: 16598, dtype: object

# %%
df[['Publisher']]
# Out:
#         Publisher
# 0        Nintendo
# 1        Nintendo
# 2        Nintendo
# 3        Nintendo
# 4        Nintendo
# ...           ...
# 16593       Kemco
# 16594  Infogrames
# 16595  Activision
# 16596    7G//AMES
# 16597     Wanadoo
#
# [16598 rows x 1 columns]

# %%
df[['Publisher']].value_counts().head(10)
# Out:
# Publisher
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
# THQ                              715
# Nintendo                         703
# Sony Computer Entertainment      683
# Sega                             639
# Take-Two Interactive             413
# dtype: int64

# %%
df.groupby("Publisher")

# %%
df.groupby("Publisher").sum().sort_values(by='Global_Sales', ascending=False).head(10)
# Out:
#                                  Rank       Year  NA_Sales  EU_Sales  \
# Publisher
# Nintendo                      2714164  1394666.0    816.87    418.74
# Electronic Arts               7140412  2686562.0    595.07    371.27
# Activision                    6368325  1938979.0    429.70    215.53
# Sony Computer Entertainment   4105604  1367034.0    265.22    187.72
# Ubisoft                       6964728  1843194.0    253.43    163.32
# Take-Two Interactive          2622275   827344.0    220.49    118.14
# THQ                           4772674  1428311.0    208.77     94.73
# Konami Digital Entertainment  7331538  1650392.0     92.16     69.69
# Sega                          5070801  1267395.0    109.40     82.00
# Namco Bandai Games            8741157  1863670.0     69.52     42.63
#
#                               JP_Sales  Other_Sales  Global_Sales
# Publisher
# Nintendo                        455.42        95.33       1786.56
# ...

# %%
df.groupby("Publisher").mean()
# Out:
#                                       Rank         Year  NA_Sales  EU_Sales  \
# Publisher
# 10TACLE Studios               14064.000000  2006.666667  0.023333  0.013333
# 1C Company                    14412.333333  2010.333333  0.003333  0.023333
# 20th Century Fox Video Games   5453.200000  1981.400000  0.364000  0.020000
# 2D Boy                        14013.000000  2008.000000  0.000000  0.030000
# 3DO                            8037.333333  2000.500000  0.180000  0.084444
# ...                                    ...          ...       ...       ...
# id Software                   14602.000000  1992.000000  0.020000  0.000000
# imageepoch Inc.               15344.000000  2014.000000  0.000000  0.000000
# inXile Entertainment          10758.000000  2015.000000  0.020000  0.060000
# mixi, Inc                      2411.000000  2015.000000  0.000000  0.000000
# responDESIGN                  12316.500000  2004.500000  0.045000  0.020000
#
# ...

# %%
df.groupby("Publisher").count()
# Out:
#                               Rank  Name  Platform  Year  Genre  NA_Sales  \
# Publisher
# 10TACLE Studios                  3     3         3     3      3         3
# 1C Company                       3     3         3     3      3         3
# 20th Century Fox Video Games     5     5         5     5      5         5
# 2D Boy                           1     1         1     1      1         1
# 3DO                             36    36        36    36     36        36
# ...                            ...   ...       ...   ...    ...       ...
# id Software                      1     1         1     1      1         1
# imageepoch Inc.                  2     2         2     2      2         2
# inXile Entertainment             1     1         1     1      1         1
# mixi, Inc                        1     1         1     1      1         1
# responDESIGN                     2     2         2     2      2         2
#
# ...

# %%
df.groupby("Publisher").agg({"Publisher":"count"}).rename(columns={"Publisher":"Number of Games"}).sort_values(by="Publisher").head(10)
# Out:
#                               Number of Games
# Publisher
# 10TACLE Studios                             3
# 1C Company                                  3
# 20th Century Fox Video Games                5
# 2D Boy                                      1
# 3DO                                        36
# 49Games                                     1
# 505 Games                                 192
# 5pb                                        61
# 7G//AMES                                    4
# 989 Sports                                  1

# %%
best_publisher = df.groupby("Publisher").agg({"Publisher":"count"}).rename(columns={"Publisher":"Number of Games"}).sort_values(by="Publisher").head(10)\
.sort_values(by="Number of Games", ascending=False)

# %%
best_publisher.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Publisher'>

# %%
df.query('Publisher == ["10TACLE Studio", "1C Company"]')
# Out:
#         Rank                             Name Platform    Year         Genre  \
# 13057  13059        Men of War: Assault Squad       PC  2011.0      Strategy
# 13724  13726                   Off-Road Drive       PC  2011.0        Racing
# 16449  16452  King's Bounty: Armored Princess       PC  2009.0  Role-Playing
#
#         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 13057  1C Company      0.01      0.03       0.0         0.01          0.05
# 13724  1C Company      0.00      0.03       0.0         0.01          0.04
# 16449  1C Company      0.00      0.01       0.0         0.00          0.01

# %%
df.groupby("Publisher").agg({"Global_Sales":["count", "sum"]})
# Out:
#                              Global_Sales
#                                     count    sum
# Publisher
# 10TACLE Studios                         3   0.11
# 1C Company                              3   0.10
# 20th Century Fox Video Games            5   1.94
# 2D Boy                                  1   0.04
# 3DO                                    36  10.12
# ...                                   ...    ...
# id Software                             1   0.03
# imageepoch Inc.                         2   0.04
# inXile Entertainment                    1   0.10
# mixi, Inc                               1   0.86
# responDESIGN                            2   0.13
#
# [578 rows x 2 columns]

# %%
# df.sort_values(by = "Global_Sales", "sum")
# Out:
#   File "<ipython-input-33-c745fbfe052e>", line 1
#     df.sort_values(by = "Global_Sales", "sum")
#                                         ^
# SyntaxError: positional argument follows keyword argument
